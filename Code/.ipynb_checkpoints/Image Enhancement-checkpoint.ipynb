# %%
import cv2
import scipy
import numpy as np
import matplotlib.pyplot as plt
from plantcv import plantcv as pcv
from scipy.interpolate import griddata
from scipy.ndimage.filters import uniform_filter

# %%
def get_non_uniform_sampling(source, steps):
    shape = np.shape(source)
    height = shape[0]
    length = shape[1]
    
    x_centre = int(length/2)
    y_centre = int(height/2)
    radius = int(min(length, height)/2)
    
    pi = np.pi
    multiplier = 0.5
    x_coordinates = []
    y_coordinates = []

    for r in steps:
        number_of_points = (1/multiplier) * 2

        for j in range(int(number_of_points)):
            theta = j*pi*multiplier
            x = x_centre + (r * np.cos(theta))
            y = y_centre + (r * np.sin(theta))
            if(x<length and y<height):
                x_coordinates.append(int(x))
                y_coordinates.append(int(y))

        multiplier = multiplier/1.75
    
    return x_coordinates, y_coordinates


def window_stdev(X, window_size):
    c1 = uniform_filter(X, window_size, mode='reflect')
    c2 = uniform_filter(X*X, window_size, mode='reflect')
    return np.sqrt(c2 - c1*c1)

# %%
img = cv2.imread("./Images/OS0043EY.JPG")
print(np.shape(img))
(B,G,R) = cv2.split(img)
#cv2.imshow("Source Image", img)
#cv2.waitKey(0)
# Out:
# (1248, 1664, 3)

# %%
steps = [0, 149, 246, 357, 486, 544, 605]
x_coordinates, y_coordinates = get_non_uniform_sampling(G, steps)
number_of_points = (np.shape(x_coordinates))[0]
print("The number of points is", number_of_points)
# Out:
# The number of points is 260

# %%
plt.figure(figsize = (8,8))
plt.imshow(G)
plt.scatter(x_coordinates, y_coordinates, color='red')
plt.colorbar()

# %%
image_window_size = 5
G_mean = cv2.blur(G, (image_window_size, image_window_size))
G_mean = np.array(G_mean, dtype=np.float32)

plt.figure(figsize = (8,8))
plt.imshow(G_mean)
plt.colorbar()

# %%
G_std = window_stdev(G, image_window_size)
G_std = np.array(G_std, dtype=np.float32)

plt.figure(figsize = (8,8))
plt.imshow(G_std)
plt.colorbar()

# %%
mean = np.empty(number_of_points)
std = np.empty(number_of_points)

for i in range(number_of_points):
    x = x_coordinates[i]
    y = y_coordinates[i]
    
    mean[i] = G_mean[y, x]
    std[i] = G_std[y, x]

# %%
xi = np.arange(0, np.shape(G)[1], 1)
yi = np.arange(0, np.shape(G)[0], 1)
x_grid, y_grid = np.meshgrid(xi, yi)

points = []
for i , j in zip(x_coordinates, y_coordinates):
    points.append([i,j])

# %%
interpolated_mean = scipy.interpolate.griddata(points, mean, (x_grid, y_grid) , method='linear', fill_value=0, rescale=False)

plt.figure(figsize = (8,8))
plt.imshow(interpolated_mean)
plt.colorbar()

# %%
interpolated_std = scipy.interpolate.griddata(points, std, (x_grid, y_grid) , method='linear', fill_value=0, rescale=False)

plt.figure(figsize = (8,8))
plt.imshow(interpolated_std)
plt.colorbar()

# %%
height = np.shape(G)[0]
length = np.shape(G)[1]

mahalanobis = np.empty(np.shape(G))
background = np.empty(np.shape(G))
foreground = np.empty(np.shape(G))

for i in range(height):
    for j in range(length):
        mahalanobis[i, j] = np.abs((G[i, j] - interpolated_mean[i, j])/interpolated_std[i, j])
        if(mahalanobis[i, j] <= 1):
            background[i, j] = mahalanobis[i, j]
# Out:
# C:\Users\aniru\AppData\Local\Temp/ipykernel_9444/1326820946.py:10: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\aniru\AppData\Local\Temp/ipykernel_9444/1326820946.py:10: RuntimeWarning: invalid value encountered in double_scalars

# %%
plt.figure(figsize = (8,8))
plt.imshow(background)
plt.colorbar()

# %%
background_window_size = 50
SA = cv2.blur(background, (background_window_size, background_window_size))
SM = window_stdev(background, background_window_size)
# Out:
# C:\Users\aniru\AppData\Local\Temp/ipykernel_9444/124088991.py:34: RuntimeWarning: invalid value encountered in sqrt

# %%
plt.figure(figsize = (8,8))
plt.imshow(SA)
plt.colorbar()

# %%
plt.figure(figsize = (8,8))
plt.imshow(SM)
plt.colorbar()

# %%
U = np.empty(np.shape(G))
for i in range(height):
    for j in range(length):
        U[i, j] = (G[i, j] - SA[i, j])/SM[i, j]
# Out:
# C:\Users\aniru\AppData\Local\Temp/ipykernel_9444/2878520282.py:4: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\aniru\AppData\Local\Temp/ipykernel_9444/2878520282.py:4: RuntimeWarning: invalid value encountered in double_scalars

# %%
plt.figure(figsize = (8,8))
plt.imshow(U)
plt.colorbar()
