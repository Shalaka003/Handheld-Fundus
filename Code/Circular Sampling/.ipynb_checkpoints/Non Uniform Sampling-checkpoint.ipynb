# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
source = cv2.imread('image.jpg', 1)
#cv2.imshow("Source Image", source)
#cv2.waitKey(0)

# %%
shape = np.shape(source)

y_centre = int(shape[0]/2)
radius = int(shape[0]/2)

# %%
steps = []
temp = radius
i = 10
while (temp - i) > 0 :
    temp = temp-i
    steps.append(temp)
    i = i+1
    
steps = np.flip(np.array(steps))
print(steps)
# Out:
# [  1  25  48  70  91 111 130 148 165 181 196 210 223 235 246]

# %%
def get_non_uniform_sampling(source_image, steps):
    source = cv2.imread('image.jpg', 1)
    shape = np.shape(source)
    y_centre = int(shape[0]/2)
    radius = int(shape[0]/2)
    
    pi = np.pi
    multiplier = 0.5
    x_coordinates = []
    y_coordinates = []

    for r in steps:
        number_of_points = (1/multiplier) * 2

        for j in range(int(number_of_points)):
            theta = j*pi*multiplier
            x = y_centre + (r * np.cos(theta))
            y = y_centre + (r * np.sin(theta))
            x_coordinates.append(int(x))
            y_coordinates.append(int(y))

        multiplier = multiplier/2
    
    return x_coordinates, y_coordinates

# %%
steps = [1, 50, 125, 175, 200, 225, 235, 250]
p, q = get_non_uniform_sampling(source, steps)
plt.rcParams['figure.figsize'] = [10,10]
plt.scatter(p, q)
